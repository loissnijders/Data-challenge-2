# %%
pip install odfpy
# Out:
# ...
#      |████████████████████████████████| 717 kB 4.5 MB/s eta 0:00:01
# ...
#   Created wheel for odfpy: filename=odfpy-1.4.1-py2.py3-none-any.whl size=137339 sha256=c4030c43be807bc7ba512f66793fbc604c778e5c7db9b4cc9193b660d51bacae
#   Stored in directory: /Users/blazej/Library/Caches/pip/wheels/e2/f4/5d/a68c656235d33455a1d0f78e877acddfa006907a6d52d7e6ee
# Successfully built odfpy
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
#in df_population there are data about age of each person per year per district
df_pupulation = pd.read_csv("Population of each district.csv")
df_police = pd.read_excel('Number of police officers per district per year.ods', engine='odf')

# %%
df_pupulation
# Out:
#        ladcode21        laname21 country  sex  age  population_2001  \
# 0      E06000001      Hartlepool       E    1    0              525
# 1      E06000001      Hartlepool       E    1    1              544
# 2      E06000001      Hartlepool       E    1    2              548
# 3      E06000001      Hartlepool       E    1    3              556
# 4      E06000001      Hartlepool       E    1    4              606
# ...          ...             ...     ...  ...  ...              ...
# 68063  W06000024  Merthyr Tydfil       W    2   86               94
# 68064  W06000024  Merthyr Tydfil       W    2   87               91
# 68065  W06000024  Merthyr Tydfil       W    2   88               88
# 68066  W06000024  Merthyr Tydfil       W    2   89               56
# 68067  W06000024  Merthyr Tydfil       W    2   90              224
#
#        population_2002  population_2003  population_2004  population_2005  \
# 0                  502              516              553              531
# ...

# %% [markdown]
# # Population per district ber year (2011 - 2021)

# %%
df2 = df_pupulation.groupby(['laname21'])[['population_2011', 'population_2012','population_2013','population_2014','population_2015','population_2016','population_2017','population_2018','population_2019','population_2020']].sum()
df2
# Out:
#                population_2011  population_2012  population_2013  \
# laname21
# Aberdeen City           222460           224910           227070
# Aberdeenshire           253650           255560           257770
# Adur                     61334            61970            62605
# Allerdale                96444            96269            96269
# Amber Valley            122521           122798           123592
# ...                        ...              ...              ...
# Wrexham                 135070           135498           135801
# Wychavon                117074           117777           118906
# Wyre                    107692           107809           108167
# Wyre Forest              98048            98087            98473
# York                    197783           199567           202113
#
#                population_2014  population_2015  population_2016  \
# laname21
# Aberdeen City           228920           230350           229840
# ...

# %% [markdown]
# # Number of officers

# %% [markdown]
# ### The values are a little bit different than is SN00634 paper and I don't know whats the reason of it (eg:  for 2011 Avon & Somerset we got 3288 and they got 3210)

# %%
df_police.head(30)
# Out:
#     As at 31 March...   Geo code       Force Name      Region  Gender  \
# 0                2007  E23000036  Avon & Somerset  South West  Female
# 1                2007  E23000036  Avon & Somerset  South West  Female
# 2                2007  E23000036  Avon & Somerset  South West  Female
# 3                2007  E23000036  Avon & Somerset  South West  Female
# 4                2007  E23000036  Avon & Somerset  South West  Female
# 5                2007  E23000036  Avon & Somerset  South West  Female
# 6                2007  E23000036  Avon & Somerset  South West  Female
# 7                2007  E23000036  Avon & Somerset  South West  Female
# 8                2007  E23000036  Avon & Somerset  South West  Female
# 9                2007  E23000036  Avon & Somerset  South West  Female
# 10               2007  E23000036  Avon & Somerset  South West  Female
# 11               2007  E23000036  Avon & Somerset  South West  Female
# ...

# %%
bb = df_police[df_police['As at 31 March...']>2010]
aa = bb[bb['Worker type']=='Police Officer']
df1 = aa.groupby(['As at 31 March...', 'Force Name'])[['Total (headcount)']].sum()
df1.head(30)
# Out:
#                                             Total (headcount)
# As at 31 March... Force Name
# 2011              Avon & Somerset                        3288
#                   Bedfordshire                           1238
#                   British Transport Police               2662
#                   Cambridgeshire                         1432
#                   Cheshire                               2106
# ...                                                       ...
# 2021              Warwickshire                           1066
#                   West Mercia                            2297
#                   West Midlands                          7319
#                   West Yorkshire                         5681
#                   Wiltshire                              1101
#
# [484 rows x 1 columns]

# %%
df1.head(30)
# Out:
#                                             Total (headcount)
# As at 31 March... Force Name
# 2011              Avon & Somerset                        3288
#                   Bedfordshire                           1238
#                   British Transport Police               2662
#                   Cambridgeshire                         1432
#                   Cheshire                               2106
#                   Cleveland                              1673
#                   Cumbria                                1208
#                   Derbyshire                             2061
#                   Devon & Cornwall                       3514
#                   Dorset                                 1497
#                   Durham                                 1454
#                   Dyfed-Powys                            1179
#                   Essex                                  3652
#                   Gloucestershire                        1305
# ...
